# %%
import scanpy as sc
import pandas as pd
import torch
from transformers import AutoModel, AutoTokenizer, AutoModelForSeq2SeqLM, Trainer, TrainingArguments, AutoModelForCausalLM, LlamaForCausalLM

# %%
tokeniser = AutoTokenizer.from_pretrained("/group/glastonbury/soumick/PretrainedWeights/Huggingface/Meta-Llama-3-8B-Instruct")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# model = AutoModelForSeq2SeqLM.from_pretrained('meta-llama/Meta-Llama-3-8B-instruct')
# model = AutoModelForSeq2SeqLM.from_pretrained('meta-llama/Meta-Llama-3-8B-instruct')
# model = LlamaForCausalLM.from_pretrained('/group/glastonbury/soumick/PretrainedWeights/Huggingface/Meta-Llama-3-8B-Instruct')
model = model = AutoModelForSeq2SeqLM.from_pretrained("/group/glastonbury/soumick/PretrainedWeights/Huggingface/Meta-Llama-3-8B-Instruct")
# model = AutoModelForCausalLM.from_pretrained("/group/glastonbury/soumick/PretrainedWeights/Huggingface/Meta-Llama-3-8B-Instruct")

# model = AutoModelForCausalLM.from_pretrained('microsoft/Phi-3-mini-128k-instruct', trust_remote_code=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 4
#       1 # model = AutoModelForSeq2SeqLM.from_pretrained('meta-llama/Meta-Llama-3-8B-instruct')
#       2 # model = AutoModelForSeq2SeqLM.from_pretrained('meta-llama/Meta-Llama-3-8B-instruct')
#       3 # model = LlamaForCausalLM.from_pretrained('/group/glastonbury/soumick/PretrainedWeights/Huggingface/Meta-Llama-3-8B-Instruct')
# ----> 4 model = model = AutoModelForSeq2SeqLM.from_pretrained("/group/glastonbury/soumick/PretrainedWeights/Huggingface/Meta-Llama-3-8B-Instruct")
#       5 # model = AutoModelForCausalLM.from_pretrained("/group/glastonbury/soumick/PretrainedWeights/Huggingface/Meta-Llama-3-8B-Instruct")
#       6
#       7 # model = AutoModelForCausalLM.from_pretrained('microsoft/Phi-3-mini-128k-instruct', trust_remote_code=True)
#
# ...

# %%
tokeniser
# Out:
# PreTrainedTokenizerFast(name_or_path='/group/glastonbury/soumick/PretrainedWeights/Huggingface/Meta-Llama-3-8B-Instruct', vocab_size=128000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|begin_of_text|>', 'eos_token': '<|end_of_text|>'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	128000: AddedToken("<|begin_of_text|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	128001: AddedToken("<|end_of_text|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	128002: AddedToken("<|reserved_special_token_0|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	128003: AddedToken("<|reserved_special_token_1|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# ...

# %%
RNA_path_original = sc.read_h5ad("/ssu/gassu/supporting_data/scTranslator/test/dataset1/GSM5008737_RNA_finetune_withcelltype.h5ad")
Pro_path_original = sc.read_h5ad("/ssu/gassu/supporting_data/scTranslator/test/dataset1/GSM5008738_protein_finetune_withcelltype.h5ad")

# %%
RNA_Pro_path_OurV0 =  sc.read_h5ad("/ssu/gassu/shared/scTranslator/input_data/10k_PBMC_3p_nextgem_Chromium_X_intron_filtered_feature_bc_matrix.scTranslate_ids.h5ad")
# Out:
# /home/soumick.chatterjee/anaconda3/envs/torchHTBeta2V2/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
RNA_path_original
# Out:
# AnnData object with n_obs × n_vars = 16177 × 23385
#     obs: 'nCount_ADT', 'nFeature_ADT', 'nCount_RNA', 'nFeature_RNA', 'orig.ident', 'lane', 'donor', 'time', 'celltype.l1', 'celltype.l2', 'celltype.l3', 'Phase', 'nCount_SCT', 'nFeature_SCT'
#     var: 'Gene symbol', 'Gene Expression', 'Entrez_Gene_Id', 'my_Id'

# %% [markdown]
# ## Experiments to perform
#
# ### Without Fine-tuning
# 1. aliceDS0_noFT_rawRNA : default params
# 2. aliceDS0_noFT_normRNA : --tag_test aliceDS0_noFT_normRNA --RNA_path /ssu/gassu/shared/scTranslator/input_data/Alice_data/clean_data_from_sina/Project_files_all/RNA_all_scrublet.scTranslatorIDs.filtered.h5ad
#
# ### Fine-tuning
# 1. aliceDS0_FT_normRNA_normPro : default params
#     1. aliceDS0_FT_normRNA_normPro_test (done with FT)
#     2.
# 2.
